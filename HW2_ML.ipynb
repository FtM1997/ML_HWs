# %%
# Fatemeh Makhloughi 
# Machine Learning
# Imam Reza Uni
import numpy as np
randomlist = np.random.randint(1,100,10)
randomlist
# Out:
# array([99, 46, 56, 95, 37, 15, 94, 69,  9, 38])

# %%
from pandas import Series
RandomNumbers = Series(np.random.randint(1,10,10), index = np.arange(1,11))
RandomNumbers
# Out:
# 1     5
# 2     5
# 3     8
# 4     9
# 5     5
# 6     8
# 7     5
# 8     1
# 9     2
# 10    7
# dtype: int64

# %%
r= RandomNumbers**2
print(r[-4:])
# Out:
# 7     25
# 8      1
# 9      4
# 10    49
# dtype: int64
